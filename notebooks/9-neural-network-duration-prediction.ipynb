# %% [markdown]
# # Neuronales Netz zur Vorhersage von Fahrtzeiten

# %% [markdown]
# Fragestellung: Prognostizieren von der Dauer einer Fahrt: Wie lange dauert wahrscheinlich eine Fahrt, wenn ich in einer bestimmten Zone zu einer bestimmten Zeit einsteige?
# Als Datenbasis für das Training werden die Taxisdaten aus dem Jahr 2019 verwendet.
# In der Folge werden hierfür zwei Testfälle betrachtet. In dem einen ersten werden die Taxidaten aus dem Jahr 2019 aufgeteilt, sodass ein Teil der Daten als Testdaten verwendet werden.
# In dem zweiten Fall werden die Daten aus einem zukünftigen Monat verwendet.

# %% [markdown]
# ## Laden der Daten

# %% [markdown]
# Zuerst werden die Daten aus der csv-Datei geladen. Hiefür wurde vorher seitens der Gruppe eine vorbearbeitete csv Datei verwendet.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import tensorflow as tf
from tensorflow import keras
import time
from datetime import datetime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
# from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
input_data = pd.read_csv("../data/processed/randomized_aggregated_for_one_year.csv")
input_data
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0            1  2019-01-23 12:08:54   2019-01-23 12:36:03              1.0
# 1            2  2019-01-20 13:16:06   2019-01-20 13:40:15              1.0
# 2            1  2019-01-18 10:21:51   2019-01-18 10:26:09              1.0
# 3            1  2019-01-14 12:13:59   2019-01-14 12:29:35              1.0
# 4            2  2019-01-09 19:56:34   2019-01-09 19:58:38              1.0
# ...        ...                  ...                   ...              ...
# 9995         1  2019-01-08 08:44:12   2019-01-08 08:53:34              1.0
# 9996         1  2019-01-09 15:25:24   2019-01-09 15:36:56              1.0
# 9997         1  2019-01-05 22:45:29   2019-01-05 23:06:28              1.0
# 9998         2  2019-01-06 04:29:16   2019-01-06 04:43:49              2.0
# 9999         1  2019-01-04 18:20:36   2019-01-04 18:30:27              1.0
#
#       trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0              4.10         1.0                  N           246
# 1             15.62         1.0                  N           132
# 2              0.90         1.0                  N           238
# 3              1.90         1.0                  N           237
# 4              0.45         1.0                  N            42
# ...             ...         ...                ...           ...
# 9995           1.70         1.0                  N           262
# 9996           1.80         1.0                  N           125
# 9997           2.30         1.0                  N            68
# 9998           5.90         1.0                  N           144
# 9999           1.70         1.0                  N           142
#
#       DOLocationID  payment_type  ...  mta_tax  tip_amount  tolls_amount  \
# 0              236             1  ...      0.5        2.00           0.0
# 1               80             1  ...      0.5       10.82           0.0
# 2              239             2  ...      0.5        0.00           0.0
# 3              164             1  ...      0.5        2.45           0.0
# 4               42             1  ...      0.5        0.00           0.0
# ...            ...           ...  ...      ...         ...           ...
# 9995           229             1  ...      0.5        1.00           0.0
# 9996           234             1  ...      0.5        2.05           0.0
# 9997           239             1  ...      0.5        4.70           0.0
# 9998           226             1  ...      0.5        2.00           0.0
# 9999           151             1  ...      0.5        2.50           0.0
#
#       improvement_surcharge  total_amount  congestion_surcharge  airport_fee  \
# 0                       0.3         22.30                   0.0          NaN
# 1                       0.3         54.12                   NaN          NaN
# 2                       0.3          6.30                   NaN          NaN
# 3                       0.3         14.75                   NaN          NaN
# 4                       0.3          5.80                   NaN          NaN
# ...                     ...           ...                   ...          ...
# 9995                    0.3         10.30                   NaN          NaN
# 9996                    0.3         12.35                   NaN          NaN
# 9997                    0.3         20.50                   NaN          NaN
# 9998                    0.3         22.80                   NaN          NaN
# 9999                    0.3         13.30                   NaN          NaN
#
#       trip_times (min)  pickup_times (unix)  Speed (mph)
# 0            27.150000         1.548242e+09     9.060773
# 1            24.150000         1.547987e+09    38.807453
# 2             4.300000         1.547803e+09    12.558140
# 3            15.600000         1.547464e+09     7.307692
# 4             2.066667         1.547060e+09    13.064516
# ...                ...                  ...          ...
# 9995          9.366667         1.546933e+09    10.889680
# 9996         11.533333         1.547044e+09     9.364162
# 9997         20.983333         1.546725e+09     6.576648
# 9998         14.550000         1.546745e+09    24.329897
# 9999          9.850000         1.546622e+09    10.355330
#
# [10000 rows x 22 columns]

# %% [markdown]
# ## Preprocessing der Daten
# Im nächsten Schritt werden die eingelesenen Daten vorbearbeitet. Wichtig ist es, dass null Werte gegen 0 ersetzt werden, auch werden die Datumswerte in Integer-Werte verändert. Zudem werden sämtliche String-Datentypen aus dem Dataframe entfernt.
# Des Weiteren werden weitere Spalten angelegt, sodass die aktuelle Uhrzeit oder der aktuelle Monat mittels Integer wiedergegeben werden kann.

# %%
input_data['tpep_pickup_datetime'] = pd.to_datetime(input_data['tpep_pickup_datetime'], format='%Y-%m-%d %H:%M:%S')
input_data['tpep_dropoff_datetime'] = pd.to_datetime(input_data['tpep_dropoff_datetime'], format='%Y-%m-%d %H:%M:%S')
input_data['trip_duration'] = (input_data['tpep_dropoff_datetime'] - input_data['tpep_pickup_datetime']).dt.seconds
input_data['PULocationID'].fillna(-1, inplace=True)
input_data['DOLocationID'].fillna(-1, inplace=True)
input_data['tpep_pickup_month'] = input_data['tpep_pickup_datetime'].dt.month
input_data['tpep_dropoff_month'] = input_data['tpep_dropoff_datetime'].dt.month
input_data['tpep_pickup_day_numeric'] = input_data['tpep_pickup_datetime'].dt.day
input_data['tpep_dropoff_day_numeric'] = input_data['tpep_dropoff_datetime'].dt.day
input_data['tpep_pickup_day_name'] = input_data['tpep_pickup_datetime'].dt.day_name()
input_data['tpep_dropoff_day_name'] = input_data['tpep_dropoff_datetime'].dt.day_name()
input_data['tpep_pickup_hour'] = input_data['tpep_pickup_datetime'].dt.hour
input_data['tpep_dropoff_hour'] = input_data['tpep_dropoff_datetime'].dt.hour
input_data['tpep_pickup_day'] = input_data['tpep_pickup_datetime'].dt.strftime("%w").astype(int)
input_data['tpep_dropoff_day'] = input_data['tpep_dropoff_datetime'].dt.strftime("%w").astype(int)
input_data['tpep_pickup_datetime'] = input_data['tpep_pickup_datetime'].apply(lambda x: int(x.strftime('%Y%m%d')))
input_data['tpep_dropoff_datetime'] = input_data['tpep_dropoff_datetime'].apply(lambda x: int(x.strftime('%Y%m%d')))
input_data = input_data.fillna(0)
input_data = input_data.drop(["tpep_dropoff_day_name"], axis=1)
input_data = input_data.drop(["tpep_pickup_day_name"], axis=1)
input_data = input_data.drop(["store_and_fwd_flag"], axis=1)

input_data
# Out:
#       VendorID  tpep_pickup_datetime  tpep_dropoff_datetime  passenger_count  \
# 0            1              20190123               20190123              1.0
# 1            2              20190120               20190120              1.0
# 2            1              20190118               20190118              1.0
# 3            1              20190114               20190114              1.0
# 4            2              20190109               20190109              1.0
# ...        ...                   ...                    ...              ...
# 9995         1              20190108               20190108              1.0
# 9996         1              20190109               20190109              1.0
# 9997         1              20190105               20190105              1.0
# 9998         2              20190106               20190106              2.0
# 9999         1              20190104               20190104              1.0
#
#       trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 0              4.10         1.0           246           236             1
# 1             15.62         1.0           132            80             1
# 2              0.90         1.0           238           239             2
# 3              1.90         1.0           237           164             1
# 4              0.45         1.0            42            42             1
# ...             ...         ...           ...           ...           ...
# 9995           1.70         1.0           262           229             1
# 9996           1.80         1.0           125           234             1
# 9997           2.30         1.0            68           239             1
# 9998           5.90         1.0           144           226             1
# 9999           1.70         1.0           142           151             1
#
#       fare_amount  ...  Speed (mph)  trip_duration  tpep_pickup_month  \
# 0            19.5  ...     9.060773           1629                  1
# 1            42.5  ...    38.807453           1449                  1
# 2             5.5  ...    12.558140            258                  1
# 3            11.5  ...     7.307692            936                  1
# 4             4.0  ...    13.064516            124                  1
# ...           ...  ...          ...            ...                ...
# 9995          8.5  ...    10.889680            562                  1
# 9996          9.5  ...     9.364162            692                  1
# 9997         14.5  ...     6.576648           1259                  1
# 9998         19.5  ...    24.329897            873                  1
# 9999          9.0  ...    10.355330            591                  1
#
#       tpep_dropoff_month  tpep_pickup_day_numeric  tpep_dropoff_day_numeric  \
# 0                      1                       23                        23
# 1                      1                       20                        20
# 2                      1                       18                        18
# 3                      1                       14                        14
# 4                      1                        9                         9
# ...                  ...                      ...                       ...
# 9995                   1                        8                         8
# 9996                   1                        9                         9
# 9997                   1                        5                         5
# 9998                   1                        6                         6
# 9999                   1                        4                         4
#
#       tpep_pickup_hour  tpep_dropoff_hour  tpep_pickup_day  tpep_dropoff_day
# 0                   12                 12                3                 3
# 1                   13                 13                0                 0
# 2                   10                 10                5                 5
# 3                   12                 12                1                 1
# 4                   19                 19                3                 3
# ...                ...                ...              ...               ...
# 9995                 8                  8                2                 2
# 9996                15                 15                3                 3
# 9997                22                 23                6                 6
# 9998                 4                  4                0                 0
# 9999                18                 18                5                 5
#
# [10000 rows x 30 columns]

# %% [markdown]
# ## Normalisierung der Daten
# In diesem Abschnitt werden die Traingsdaten normalisiert. Im Anschluss werden diese in einen Trainings- sowie Testdatensatz aufgeteilt.

# %%
#Definition der Features und der TargetVariable (y)
Features = ['PULocationID', 'DOLocationID', 'tpep_pickup_month', 'tpep_pickup_day', 'tpep_pickup_hour']
TargetVariable = ['trip_times (min)']

#laden der Daten in einen seperaten Dataframe
X = input_data[Features].values
y = input_data[TargetVariable].values

# definiert StandardScaler für das normalisieren Daten
PredictorScaler = StandardScaler()
TargetVarScaler = StandardScaler()

# identifiziert das minimum und maximum Daten für die spätere Transformation
PredictorScalerFit = PredictorScaler.fit(X)
TargetVarScalerFit = TargetVarScaler.fit(y)

# transformiert die Daten (Normalisierung)
X = PredictorScalerFit.transform(X)
y = TargetVarScalerFit.transform(y)

#teilt die Daten in Test- und Traingsdaten auf (30% Testdaten, 70% Trainingsdaten)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (7000, 5)
# (7000, 1)
# (3000, 5)
# (3000, 1)

# %% [markdown]
# ## Modelldefintion für das Regressionsmodell

# %%
model = Sequential([
    Dense(units=32, input_dim=X_train.shape[1], activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=32, activation='relu'),
    Flatten(),
    Dense(units=1)
])
model.summary()

model.compile(optimizer=Adam(), loss='mean_squared_error', metrics=['mean_squared_error'])
model.fit(x=X_train, y=y_train, batch_size=100, epochs=20, shuffle=True,
          verbose=2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 32)                192
#
#  dense_5 (Dense)             (None, 32)                1056
#
#  dense_6 (Dense)             (None, 32)                1056
#
#  flatten_1 (Flatten)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,337
# Trainable params: 2,337
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 70/70 - 1s - loss: 1.0105 - mean_squared_error: 1.0105 - 1s/epoch - 17ms/step
# Epoch 2/20
# 70/70 - 0s - loss: 0.9894 - mean_squared_error: 0.9894 - 113ms/epoch - 2ms/step
# Epoch 3/20
# 70/70 - 0s - loss: 0.9909 - mean_squared_error: 0.9909 - 97ms/epoch - 1ms/step
# Epoch 4/20
# 70/70 - 0s - loss: 0.9899 - mean_squared_error: 0.9899 - 121ms/epoch - 2ms/step
# Epoch 5/20
# 70/70 - 0s - loss: 0.9827 - mean_squared_error: 0.9827 - 115ms/epoch - 2ms/step
# Epoch 6/20
# 70/70 - 0s - loss: 0.9786 - mean_squared_error: 0.9786 - 107ms/epoch - 2ms/step
# Epoch 7/20
# 70/70 - 0s - loss: 0.9760 - mean_squared_error: 0.9760 - 112ms/epoch - 2ms/step
# Epoch 8/20
# 70/70 - 0s - loss: 0.9753 - mean_squared_error: 0.9753 - 96ms/epoch - 1ms/step
# Epoch 9/20
# 70/70 - 0s - loss: 0.9759 - mean_squared_error: 0.9759 - 115ms/epoch - 2ms/step
# Epoch 10/20
# 70/70 - 0s - loss: 0.9708 - mean_squared_error: 0.9708 - 119ms/epoch - 2ms/step
# Epoch 11/20
# 70/70 - 0s - loss: 0.9689 - mean_squared_error: 0.9689 - 119ms/epoch - 2ms/step
# Epoch 12/20
# 70/70 - 0s - loss: 0.9672 - mean_squared_error: 0.9672 - 118ms/epoch - 2ms/step
# Epoch 13/20
# 70/70 - 0s - loss: 0.9666 - mean_squared_error: 0.9666 - 109ms/epoch - 2ms/step
# Epoch 14/20
# 70/70 - 0s - loss: 0.9639 - mean_squared_error: 0.9639 - 131ms/epoch - 2ms/step
# Epoch 15/20
# 70/70 - 0s - loss: 0.9652 - mean_squared_error: 0.9652 - 105ms/epoch - 2ms/step
# Epoch 16/20
# 70/70 - 0s - loss: 0.9620 - mean_squared_error: 0.9620 - 111ms/epoch - 2ms/step
# Epoch 17/20
# 70/70 - 0s - loss: 0.9659 - mean_squared_error: 0.9659 - 107ms/epoch - 2ms/step
# Epoch 18/20
# 70/70 - 0s - loss: 0.9651 - mean_squared_error: 0.9651 - 114ms/epoch - 2ms/step
# Epoch 19/20
# 70/70 - 0s - loss: 0.9688 - mean_squared_error: 0.9688 - 130ms/epoch - 2ms/step
# Epoch 20/20
# 70/70 - 0s - loss: 0.9604 - mean_squared_error: 0.9604 - 120ms/epoch - 2ms/step

# %%
#Vorhersage mit dem Testdaten
Predictions = model.predict(X_test)

# die inversive Transformation der Vorhersagen, labeldaten und Testdaten
Predictions = TargetVarScalerFit.inverse_transform(Predictions)
y_test_orig = TargetVarScalerFit.inverse_transform(y_test)
Test_Data = PredictorScalerFit.inverse_transform(X_test)

#Erstellen eines neuen Dataframes mit den vorhergesagten Fahrtzeiten und den tatsächlichen Fahrtzeiten
TestingData = pd.DataFrame(data=Test_Data, columns=Features)
TestingData['trip_time (min)'] = y_test_orig
TestingData['predicted trip time'] = Predictions
TestingData.head(10)
# Out:
# 94/94 [==============================] - 0s 1ms/step
#    PULocationID  DOLocationID  tpep_pickup_month  tpep_pickup_day  \
# 0         236.0         237.0                1.0              0.0
# 1         142.0         114.0                1.0              1.0
# 2         238.0         246.0                1.0              6.0
# 3          13.0         144.0                1.0              6.0
# 4         141.0         229.0                1.0              3.0
# 5         161.0          68.0                1.0              5.0
# 6         162.0         186.0                1.0              3.0
# 7         132.0         123.0                1.0              4.0
# 8         246.0          68.0                1.0              6.0
# 9         236.0         238.0                1.0              1.0
#
#    tpep_pickup_hour  trip_time (min)  predicted trip time
# 0              16.0         3.550000             8.237384
# 1              20.0        15.500000            14.407620
# 2               7.0         6.833333            10.909443
# 3              12.0        15.800000            13.552885
# 4              15.0        14.233333            16.337107
# 5              18.0         8.483333            16.282545
# 6              16.0        10.883333            13.891435
# 7              19.0        34.016667            13.718861
# 8              16.0         4.916667            11.548320
# 9              14.0        12.700000             9.453067

# %% [markdown]
# ## Zweiter Testdatensatz: Vorhersage für Fahrten aus dem Jahr 2020 (Mai)
# In dem diesem Abschnitt werden nun Testdaten aus dem Jahr 2020 verwendet. Für diese Testdaten soll das vorher erstellte Model nun Vorhersagen erstellen

# %% [markdown]
# Im ersten Schritt wird die csv Datei geladen. Daraufhin wird ein identisches Preprocessing der Daten durchgeführt.

# %%
# Einlesen einer weiteren csv aus dem nächsten Jahr
input_test_data = pd.read_csv("../data/processed/yellow_tripdata_2020-05.csv", nrows=50)

#Data preprocesssing
input_test_data['tpep_pickup_datetime'] = pd.to_datetime(input_test_data['tpep_pickup_datetime'],
                                                         format='%Y-%m-%d %H:%M:%S')
input_test_data['tpep_dropoff_datetime'] = pd.to_datetime(input_test_data['tpep_dropoff_datetime'],
                                                          format='%Y-%m-%d %H:%M:%S')
input_test_data['trip_duration'] = (
        input_test_data['tpep_dropoff_datetime'] - input_test_data['tpep_pickup_datetime']).dt.seconds
input_test_data['trip_times (min)'] = input_test_data['trip_duration'].apply(lambda x: x / 60)
input_test_data['PULocationID'].fillna(-1, inplace=True)
input_test_data['DOLocationID'].fillna(-1, inplace=True)
input_test_data['tpep_pickup_month'] = input_test_data['tpep_pickup_datetime'].dt.month
input_test_data['tpep_dropoff_month'] = input_test_data['tpep_dropoff_datetime'].dt.month
input_test_data['tpep_pickup_day_numeric'] = input_test_data['tpep_pickup_datetime'].dt.day
input_test_data['tpep_dropoff_day_numeric'] = input_test_data['tpep_dropoff_datetime'].dt.day
input_test_data['tpep_pickup_day_name'] = input_test_data['tpep_pickup_datetime'].dt.day_name()
input_test_data['tpep_dropoff_day_name'] = input_test_data['tpep_dropoff_datetime'].dt.day_name()
input_test_data['tpep_pickup_hour'] = input_test_data['tpep_pickup_datetime'].dt.hour
input_test_data['tpep_dropoff_hour'] = input_test_data['tpep_dropoff_datetime'].dt.hour
input_test_data['tpep_pickup_day'] = input_test_data['tpep_pickup_datetime'].dt.strftime("%w").astype(int)
input_test_data['tpep_dropoff_day'] = input_test_data['tpep_dropoff_datetime'].dt.strftime("%w").astype(int)
input_test_data['tpep_pickup_datetime'] = input_test_data['tpep_pickup_datetime'].apply(
    lambda x: int(x.strftime('%Y%m%d')))
input_test_data['tpep_dropoff_datetime'] = input_test_data['tpep_dropoff_datetime'].apply(
    lambda x: int(x.strftime('%Y%m%d')))
input_test_data = input_test_data.fillna(0)
input_test_data = input_test_data.drop(["tpep_dropoff_day_name"], axis=1)
input_test_data = input_test_data.drop(["tpep_pickup_day_name"], axis=1)
input_test_data = input_test_data.drop(["store_and_fwd_flag"], axis=1)
input_test_data
# Out:
#     VendorID  tpep_pickup_datetime  tpep_dropoff_datetime  passenger_count  \
# 0          1              20200501               20200501              1.0
# 1          1              20200501               20200501              2.0
# 2          1              20200501               20200501              1.0
# 3          1              20200501               20200501              1.0
# 4          1              20200501               20200501              0.0
# 5          1              20200501               20200501              0.0
# 6          1              20200501               20200501              1.0
# 7          1              20200501               20200501              1.0
# 8          1              20200501               20200501              1.0
# 9          1              20200501               20200501              1.0
# 10         2              20200501               20200501              1.0
# 11         2              20200501               20200501              1.0
# 12         2              20200501               20200501              1.0
# 13         2              20200501               20200501              1.0
# 14         2              20200501               20200501              1.0
# 15         2              20200501               20200501              1.0
# 16         1              20200501               20200501              1.0
# 17         1              20200501               20200501              1.0
# 18         1              20200501               20200501              1.0
# 19         2              20200501               20200501              4.0
# 20         2              20200501               20200501              1.0
# 21         2              20200501               20200501              1.0
# 22         2              20200501               20200501              1.0
# 23         1              20200501               20200501              1.0
# 24         2              20200501               20200501              1.0
# 25         1              20200501               20200501              1.0
# 26         1              20200501               20200501              1.0
# 27         2              20200501               20200501              1.0
# 28         2              20200501               20200501              1.0
# 29         1              20200501               20200501              1.0
# 30         2              20200501               20200501              2.0
# 31         2              20200501               20200501              3.0
# 32         2              20200501               20200501              6.0
# 33         2              20200501               20200501              1.0
# 34         2              20200501               20200501              1.0
# 35         2              20200501               20200501              1.0
# 36         2              20200501               20200501              1.0
# 37         2              20200501               20200501              1.0
# 38         2              20200501               20200501              1.0
# 39         2              20200501               20200501              1.0
# 40         2              20200501               20200501              1.0
# 41         2              20200501               20200501              1.0
# 42         2              20200501               20200501              1.0
# 43         1              20200501               20200501              1.0
# 44         1              20200501               20200501              1.0
# 45         1              20200501               20200501              1.0
# 46         2              20200501               20200501              1.0
# 47         2              20200501               20200501              1.0
# 48         1              20200501               20200501              1.0
# 49         1              20200501               20200501              1.0
#
#     trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 0            0.00         1.0           234           256             1
# 1            0.40         1.0           264           264             1
# 2            0.30         1.0           264           264             2
# 3            1.70         1.0           107           229             2
# 4            0.90         1.0           237           262             1
# 5           12.00         1.0           140            28             1
# 6            2.90         1.0            79           237             2
# 7            1.50         1.0           140           263             1
# 8            2.00         1.0           140           230             2
# 9            0.50         1.0           239           239             2
# 10           3.37         1.0           151           244             1
# 11           1.41         1.0           152            41             2
# 12           1.06         1.0           107           137             2
# 13           0.73         1.0            48           163             2
# 14           0.90         1.0           143           239             1
# 15           0.75         1.0            48            48             1
# 16           2.40         1.0           263           170             1
# 17           1.10         1.0           107             4             2
# 18           6.40         1.0            75           169             1
# 19           2.89         1.0           263           161             1
# 20           0.91         1.0           107           164             1
# 21           3.64         1.0           137            66             2
# 22           4.91         1.0            65           186             2
# 23           6.00         1.0           233           168             1
# 24           1.05         1.0           137           233             1
# 25           8.80         1.0           113            14             1
# 26           4.40         1.0            90           238             2
# 27           7.26         1.0            66            26             1
# 28           0.61         1.0           188           188             2
# 29           0.60         1.0           141           141             1
# 30           0.92         1.0           230            68             2
# 31           8.37         1.0            75            88             1
# 32           5.06         1.0           137            74             1
# 33           0.62         1.0           229           161             4
# 34           0.62         1.0           229           161             2
# 35           2.50         1.0           237            75             1
# 36           3.67         1.0           137           263             2
# 37           1.17         1.0           137           170             1
# 38           2.59         1.0           244           169             2
# 39           1.87         1.0           137           237             2
# 40           2.81         1.0           100           238             1
# 41           1.32         1.0            75           263             4
# 42           1.32         1.0            75           263             2
# 43           1.00         1.0            79           249             2
# 44           1.50         1.0           107           148             2
# 45           0.00         1.0           137            69             1
# 46           1.66         1.0           236            74             1
# 47           2.63         1.0           186           141             2
# 48           3.70         1.0            48           152             2
# 49           1.60         1.0            75           151             2
#
#     fare_amount  ...  trip_duration  trip_times (min)  tpep_pickup_month  \
# 0          12.2  ...            939         15.650000                  5
# 1           4.0  ...            160          2.666667                  5
# 2           3.5  ...            133          2.216667                  5
# 3           7.0  ...            336          5.600000                  5
# 4           6.0  ...            367          6.116667                  5
# 5          35.5  ...           1471         24.516667                  5
# 6          12.0  ...           1078         17.966667                  5
# 7           7.0  ...            370          6.166667                  5
# 8           9.0  ...            589          9.816667                  5
# 9           4.5  ...            204          3.400000                  5
# 10         13.0  ...            752         12.533333                  5
# 11          7.0  ...            443          7.383333                  5
# 12          6.0  ...            334          5.566667                  5
# 13          6.5  ...            474          7.900000                  5
# 14          5.5  ...            307          5.116667                  5
# 15          5.0  ...            246          4.100000                  5
# 16          8.5  ...            315          5.250000                  5
# 17          6.0  ...            290          4.833333                  5
# 18         20.5  ...           1071         17.850000                  5
# 19         10.5  ...            551          9.183333                  5
# 20          5.5  ...            314          5.233333                  5
# 21         13.0  ...            704         11.733333                  5
# 22         17.0  ...           1090         18.166667                  5
# 23         18.0  ...            726         12.100000                  5
# 24          5.0  ...            185          3.083333                  5
# 25         26.0  ...           1102         18.366667                  5
# 26         15.5  ...           1005         16.750000                  5
# 27         22.5  ...           1200         20.000000                  5
# 28          5.0  ...            271          4.516667                  5
# 29          4.0  ...            148          2.466667                  5
# 30          5.0  ...            193          3.216667                  5
# 31         26.5  ...           1881         31.350000                  5
# 32         15.5  ...            921         15.350000                  5
# 33         -4.5  ...            203          3.383333                  5
# 34          4.5  ...            203          3.383333                  5
# 35          9.0  ...            390          6.500000                  5
# 36         12.0  ...            467          7.783333                  5
# 37          6.0  ...            329          5.483333                  5
# 38         10.5  ...            580          9.666667                  5
# 39          8.0  ...            388          6.466667                  5
# 40         11.0  ...            632         10.533333                  5
# 41         -8.0  ...            578          9.633333                  5
# 42          8.0  ...            578          9.633333                  5
# 43          6.5  ...            370          6.166667                  5
# 44          7.5  ...            386          6.433333                  5
# 45         27.2  ...            937         15.616667                  5
# 46          6.5  ...            274          4.566667                  5
# 47          9.5  ...            457          7.616667                  5
# 48         12.5  ...            601         10.016667                  5
# 49          7.0  ...            283          4.716667                  5
#
#     tpep_dropoff_month  tpep_pickup_day_numeric  tpep_dropoff_day_numeric  \
# 0                    5                        1                         1
# 1                    5                        1                         1
# 2                    5                        1                         1
# 3                    5                        1                         1
# 4                    5                        1                         1
# 5                    5                        1                         1
# 6                    5                        1                         1
# 7                    5                        1                         1
# 8                    5                        1                         1
# 9                    5                        1                         1
# 10                   5                        1                         1
# 11                   5                        1                         1
# 12                   5                        1                         1
# 13                   5                        1                         1
# 14                   5                        1                         1
# 15                   5                        1                         1
# 16                   5                        1                         1
# 17                   5                        1                         1
# 18                   5                        1                         1
# 19                   5                        1                         1
# 20                   5                        1                         1
# 21                   5                        1                         1
# 22                   5                        1                         1
# 23                   5                        1                         1
# 24                   5                        1                         1
# 25                   5                        1                         1
# 26                   5                        1                         1
# 27                   5                        1                         1
# 28                   5                        1                         1
# 29                   5                        1                         1
# 30                   5                        1                         1
# 31                   5                        1                         1
# 32                   5                        1                         1
# 33                   5                        1                         1
# 34                   5                        1                         1
# 35                   5                        1                         1
# 36                   5                        1                         1
# 37                   5                        1                         1
# 38                   5                        1                         1
# 39                   5                        1                         1
# 40                   5                        1                         1
# 41                   5                        1                         1
# 42                   5                        1                         1
# 43                   5                        1                         1
# 44                   5                        1                         1
# 45                   5                        1                         1
# 46                   5                        1                         1
# 47                   5                        1                         1
# 48                   5                        1                         1
# 49                   5                        1                         1
#
#     tpep_pickup_hour  tpep_dropoff_hour  tpep_pickup_day  tpep_dropoff_day
# 0                  0                  0                5                 5
# 1                  0                  0                5                 5
# 2                  0                  0                5                 5
# 3                  0                  0                5                 5
# 4                  0                  1                5                 5
# 5                  0                  1                5                 5
# 6                  0                  0                5                 5
# 7                  0                  0                5                 5
# 8                  0                  1                5                 5
# 9                  0                  0                5                 5
# 10                 0                  0                5                 5
# 11                 0                  0                5                 5
# 12                 0                  0                5                 5
# 13                 0                  1                5                 5
# 14                 0                  0                5                 5
# 15                 0                  0                5                 5
# 16                 0                  0                5                 5
# 17                 0                  0                5                 5
# 18                 0                  0                5                 5
# 19                 0                  0                5                 5
# 20                 0                  0                5                 5
# 21                 0                  0                5                 5
# 22                 0                  1                5                 5
# 23                 0                  0                5                 5
# 24                 0                  0                5                 5
# 25                 0                  0                5                 5
# 26                 0                  0                5                 5
# 27                 0                  0                5                 5
# 28                 0                  0                5                 5
# 29                 0                  0                5                 5
# 30                 0                  0                5                 5
# 31                 0                  0                5                 5
# 32                 0                  0                5                 5
# 33                 0                  0                5                 5
# 34                 0                  0                5                 5
# 35                 0                  0                5                 5
# 36                 0                  0                5                 5
# 37                 0                  0                5                 5
# 38                 0                  0                5                 5
# 39                 0                  0                5                 5
# 40                 0                  0                5                 5
# 41                 0                  0                5                 5
# 42                 0                  0                5                 5
# 43                 0                  0                5                 5
# 44                 0                  0                5                 5
# 45                 0                  0                5                 5
# 46                 0                  0                5                 5
# 47                 0                  0                5                 5
# 48                 0                  0                5                 5
# 49                 0                  0                5                 5
#
# [50 rows x 28 columns]

# %% [markdown]
# ## Normalisierung der Daten
# In diesem Schritt wird analog zu der vorherigen Normalisierung vorgegenagen. Nur in diesem Fall ist es nicht notwenig die labels seperat zu transformieren.

# %%
#laden der Daten in einen seperaten Dataframe
X_test_features = input_test_data[Features].values
y_test_target = input_test_data[TargetVariable].values

# definiert StandardScaler für das normalisieren Daten
test_PredictorScaler = StandardScaler()
test_TargetVarScaler = StandardScaler()

# identifiziert das minimum und maximum Daten für die spätere Transformation
test_TargetVarScalerFit = test_TargetVarScaler.fit(y_test_target)
test_PredictorScaler = test_PredictorScaler.fit(X_test_features)

# Transformation der Testdaten
X_test_features = test_PredictorScaler.transform(X_test_features)

# %%
# vorhersage mit den Testdaten
second_predictions = model.predict(X_test_features)

# die inversive Transformation der Vorhersagen und Testdaten
second_predictions = test_TargetVarScaler.inverse_transform(second_predictions)
second_Test_Data = test_PredictorScaler.inverse_transform(X_test_features)

#Erstellen eines neuen Dataframes mit den vorhergesagten Fahrtzeiten und den tatsächlichen Fahrtzeiten
second_TestingData = pd.DataFrame(data=second_Test_Data, columns=Features)
second_TestingData['trip_times (min)'] = y_test_target
second_TestingData['predicted trip time'] = second_predictions
second_TestingData.head(30)
# Out:
# 2/2 [==============================] - 0s 3ms/step
#     PULocationID  DOLocationID  tpep_pickup_month  tpep_pickup_day  \
# 0          234.0         256.0                5.0              5.0
# 1          264.0         264.0                5.0              5.0
# 2          264.0         264.0                5.0              5.0
# 3          107.0         229.0                5.0              5.0
# 4          237.0         262.0                5.0              5.0
# 5          140.0          28.0                5.0              5.0
# 6           79.0         237.0                5.0              5.0
# 7          140.0         263.0                5.0              5.0
# 8          140.0         230.0                5.0              5.0
# 9          239.0         239.0                5.0              5.0
# 10         151.0         244.0                5.0              5.0
# 11         152.0          41.0                5.0              5.0
# 12         107.0         137.0                5.0              5.0
# 13          48.0         163.0                5.0              5.0
# 14         143.0         239.0                5.0              5.0
# 15          48.0          48.0                5.0              5.0
# 16         263.0         170.0                5.0              5.0
# 17         107.0           4.0                5.0              5.0
# 18          75.0         169.0                5.0              5.0
# 19         263.0         161.0                5.0              5.0
# 20         107.0         164.0                5.0              5.0
# 21         137.0          66.0                5.0              5.0
# 22          65.0         186.0                5.0              5.0
# 23         233.0         168.0                5.0              5.0
# 24         137.0         233.0                5.0              5.0
# 25         113.0          14.0                5.0              5.0
# 26          90.0         238.0                5.0              5.0
# 27          66.0          26.0                5.0              5.0
# 28         188.0         188.0                5.0              5.0
# 29         141.0         141.0                5.0              5.0
#
#     tpep_pickup_hour  trip_times (min)  predicted trip time
# 0                0.0         15.650000             7.767965
# 1                0.0          2.666667             7.438802
# 2                0.0          2.216667             7.438802
# 3                0.0          5.600000            11.520551
# 4                0.0          6.116667             7.695323
# 5                0.0         24.516667            12.675119
# 6                0.0         17.966667            11.235487
# 7                0.0          6.166667            10.561889
# 8                0.0          9.816667            10.793690
# 9                0.0          3.400000             7.922767
# 10               0.0         12.533333            10.161532
# 11               0.0          7.383333            12.401723
# 12               0.0          5.566667            10.392147
# 13               0.0          7.900000            11.134997
# 14               0.0          5.116667            10.566649
# 15               0.0          4.100000             8.263447
# 16               0.0          5.250000             9.319150
# 17               0.0          4.833333            12.821300
# 18               0.0         17.850000            10.968820
# 19               0.0          9.183333             9.516644
# 20               0.0          5.233333            11.001768
# 21               0.0         11.733333            12.091312
# 22               0.0         18.166667            10.813533
# 23               0.0         12.100000             9.561164
# 24               0.0          3.083333            10.894963
# 25               0.0         18.366667            12.846051
# 26               0.0         16.750000            11.416915
# 27               0.0         20.000000             9.529640
# 28               0.0          4.516667             9.157291
# 29               0.0          2.466667            10.785263

# %% [markdown]
# ## Visualisierung der Ergebnisse
# Nun
# werden
# die
# vorhergesagten
# Fahrtzeiten
# mit
# den
# tatsächlichen
# Fahrtzeiten
# gegenüber
# gestellt

# %%
plt.plot(second_TestingData['trip_times (min)'], color='red', label='Echten Fahrten')
plt.plot(second_TestingData['predicted trip time'], color='blue', label='Vorhergesagte Fahrten')
plt.title('Gegenüberstellung der vorhergesagten und tatsächlichen Fahrtzeiten')
plt.xlabel('Fahrtnummer')
plt.ylabel('Fahrtzeit (in Minuten))')
plt.legend()
plt.figure(figsize=(1000, 1000))
plt.show()

# %% [markdown]
# In dem folgenden Diagramm wird die Regressionsergebnisse in einem Scatter dargestellt.

# %%
sn.regplot(x='trip_times (min)', y='predicted trip time', data=second_TestingData)
# Out:
# <AxesSubplot:xlabel='trip_times (min)', ylabel='predicted trip time'>
